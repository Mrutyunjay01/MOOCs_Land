# %%
import pandas as pd
wine_reviews = pd.read_csv("../winemag-data_first150k.csv")
wine_reviews.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %% [markdown]
# # Summary functions
# -> Used for restructuring our data
# .describe() Method
# -> Generates a high level summary of the attributes of the given column
# -> It is a type-aware, means that its output changes based on the data type of the input.
# -> The output only makes sense for numeric data type only. Not for strings.

# %%
wine_reviews.points.describe()
# Out:
# count    150930.000000
# mean         87.888418
# std           3.222392
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: points, dtype: float64

# %%
wine_reviews.province.describe()
# Out:
# count         150925
# unique           455
# top       California
# freq           44508
# Name: province, dtype: object

# %%
# .mean() method gives the mean value of a numeric column
wine_reviews.points.mean()
# Out:
# 87.8884184721394

# %%
# to see a list of unique keys, we use .unique() method
wine_reviews.province.unique()
# Out:
# array(['California', 'Northern Spain', 'Oregon', 'Provence',
#        'Northeastern Italy', 'Southwest France', 'Kumeu', 'Washington',
#        'Bulgaria', 'Tuscany', 'France Other', 'Rhône Valley', 'Galicia',
#        'Andalucia', 'Idaho', 'Burgundy', 'Loire Valley', 'New York',
#        'Mendoza Province', 'Victoria', 'Alentejano', 'Piedmont',
#        'Alentejo', 'Champagne', 'Upper Galilee', 'Beira Atlantico',
#        'Veneto', 'Douro', 'Tejo', 'Stellenbosch', 'Levante',
#        'Sicily & Sardinia', 'Southern Italy', 'Languedoc-Roussillon',
#        'Bordeaux', 'Atalanti Valley', 'Catalonia', 'Santorini', 'Florina',
#        'Marchigue', 'Colchagua Valley', 'Curicó Valley', 'Nemea',
#        'Maule Valley', 'Alsace', 'Guerrouane', 'Colinele Dobrogei',
#        'Central Spain', 'Vinho Verde', 'Mosel', 'Rheinhessen',
#        'Golan Heights', 'Württemberg', 'Ahr', 'British Columbia',
#        'Moldova', 'Spain Other', 'Sopron', 'Other', 'Walker Bay', 'Dão',
# ...

# %%
# To see a list of unique values and how often they occur in the dataset, we use the .value_counts() Method
wine_reviews.province.value_counts()
# Out:
# California         44508
# Washington          9750
# Tuscany             7281
# Bordeaux            6111
# Northern Spain      4892
#                    ...
# Colchagua Costa        1
# Zitsa                  1
# Limnos                 1
# Dalmatian Coast        1
# Dolenjska              1
# Name: province, Length: 455, dtype: int64

# %% [markdown]
# # MAP
# ~ A map is a function : it takes values of one set and maps them to another set of values.
# -> .map() Method
# ` Say we want to remean the points to zero. We can do as following:

# %%
wine_reviews_points_mean = wine_reviews.points.mean()
wine_reviews.points.map(lambda p : p - wine_reviews_points_mean)
# Out:
# 0         8.111582
# 1         8.111582
# 2         8.111582
# 3         8.111582
# 4         7.111582
#             ...
# 150925    3.111582
# 150926    3.111582
# 150927    3.111582
# 150928    2.111582
# 150929    2.111582
# Name: points, Length: 150930, dtype: float64

# %% [markdown]
# ### map()
# > Expects a single value from the Series and returns a transformed version of that vlaue. It returns a new Series where all the values have been transformed by the function.
# ### apply()
# > Equivalent method if we want to tranform a whole DataFrame by calling a custom method on each row.

# %%
def remean_points(row):
    row.points = row.points - wine_reviews_points_mean
    return row

wine_reviews.apply(remean_points, axis='columns')
# Out:
#         Unnamed: 0 country                                        description  \
# 0                0      US  This tremendous 100% varietal wine hails from ...
# 1                1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                2      US  Mac Watson honors the memory of a wine once ma...
# 3                3      US  This spent 20 months in 30% new French oak, an...
# 4                4  France  This is the top wine from La Bégude, named aft...
# ...            ...     ...                                                ...
# 150925      150925   Italy  Many people feel Fiano represents southern Ita...
# 150926      150926  France  Offers an intriguing nose with ginger, lime an...
# 150927      150927   Italy  This classic example comes from a cru vineyard...
# 150928      150928  France  A perfect salmon shade, with scents of peaches...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %% [markdown]
#     If we had called wine_reviews.apply() with axis='index', then instead of passing a function to transform each row, we would need to give a function to tranform each column.

# %% [markdown]
# [] map() and apply() return new, transformed Series and Dataframes, respectively. They dont modify the original data they are called on. We dont loose our original data here.
